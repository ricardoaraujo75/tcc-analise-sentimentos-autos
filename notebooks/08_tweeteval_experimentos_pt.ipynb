# %% [markdown]
# # Experimentos com TweetEval e Modelos Pré-Treinados em Português
#
# Este notebook realiza testes de análise de sentimentos utilizando modelos disponíveis no Hugging Face, incluindo TweetEval e modelos em português (ex.: BERTimbau).

# %%
# !pip install torch torchvision torchaudio transformers datasets tiktoken protobuf --quiet
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Importando bibliotecas

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
from datasets import load_dataset
from huggingface_hub import login

print('bibliotecas importadas')
# Out:
# bibliotecas importadas

# %% [markdown]
# ## Login

# %%
login("")

print('login realizado.')
# Out:
# login realizado.

# %% [markdown]
# ## Carregando modelo multilíngue (ex.: BERT Multilingual)

# %%
model_name = 'nlptown/bert-base-multilingual-uncased-sentiment'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

sentiment_pipeline = pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)

exemplo = 'O HB20 é um carro econômico, mas tem pouco espaço interno.'
print(sentiment_pipeline(exemplo))
# Out:
# Device set to use mps:0
# [{'label': '3 stars', 'score': 0.5784284472465515}]

# %% [markdown]
# ## Carregando modelo em Português (BERTimbau + fine-tuning para sentimentos)

# %%
model_name_pt = 'cardiffnlp/twitter-xlm-roberta-base-sentiment'
tokenizer_pt = AutoTokenizer.from_pretrained(model_name_pt)
model_pt = AutoModelForSequenceClassification.from_pretrained(model_name_pt)

sentiment_pipeline_pt = pipeline('sentiment-analysis', model=model_pt, tokenizer=tokenizer_pt)

exemplo_pt = 'O Onix tem bom consumo, mas o espaço traseiro poderia ser melhor.'
print(sentiment_pipeline_pt(exemplo_pt))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/convert_slow_tokenizer.py:1737, in convert_slow_tokenizer(transformer_tokenizer, from_tiktoken)
#    1733     logger.info("Converting from Tiktoken")
#    1734     return TikTokenConverter(
#    1735         vocab_file=transformer_tokenizer.vocab_file,
#    1736         additional_special_tokens=transformer_tokenizer.additional_special_tokens,
# -> 1737     ).converted()
#    1738 except Exception:
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/convert_slow_tokenizer.py:1631, in TikTokenConverter.converted(self)
#    1630 def converted(self) -> Tokenizer:
# -> 1631     tokenizer = self.tokenizer()
#    1632     tokenizer.pre_tokenizer = pre_tokenizers.Sequence(
#    1633         [
#    1634             pre_tokenizers.Split(Regex(self.pattern), behavior="isolated", invert=False),
#    1635             pre_tokenizers.ByteLevel(add_prefix_space=self.add_prefix_space, use_regex=False),
#    1636         ]
#    1637     )
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/convert_slow_tokenizer.py:1624, in TikTokenConverter.tokenizer(self)
#    1623 def tokenizer(self):
# -> 1624     vocab_scores, merges = self.extract_vocab_merges_from_model(self.vocab_file)
#    1625     tokenizer = Tokenizer(BPE(vocab_scores, merges, fuse_unk=False))
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/convert_slow_tokenizer.py:1600, in TikTokenConverter.extract_vocab_merges_from_model(self, tiktoken_url)
#    1596     raise ValueError(
#    1597         "`tiktoken` is required to read a `tiktoken` file. Install it with `pip install tiktoken`."
#    1598     )
# -> 1600 bpe_ranks = load_tiktoken_bpe(tiktoken_url)
#    1601 byte_encoder = bytes_to_unicode()
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/tiktoken/load.py:158, in load_tiktoken_bpe(tiktoken_bpe_file, expected_hash)
#     156 def load_tiktoken_bpe(tiktoken_bpe_file: str, expected_hash: str | None = None) -> dict[bytes, int]:
#     157     # NB: do not add caching to this function
# --> 158     contents = read_file_cached(tiktoken_bpe_file, expected_hash)
#     159     ret = {}
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/tiktoken/load.py:48, in read_file_cached(blobpath, expected_hash)
#      46     return read_file(blobpath)
# ---> 48 cache_key = hashlib.sha1(blobpath.encode()).hexdigest()
#      50 cache_path = os.path.join(cache_dir, cache_key)
#
# AttributeError: 'NoneType' object has no attribute 'encode'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 model_name_pt = 'cardiffnlp/twitter-xlm-roberta-base-sentiment'
# ----> 2 tokenizer_pt = AutoTokenizer.from_pretrained(model_name_pt)
#       3 model_pt = AutoModelForSequenceClassification.from_pretrained(model_name_pt)
#       5 sentiment_pipeline_pt = pipeline('sentiment-analysis', model=model_pt, tokenizer=tokenizer_pt)
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/models/auto/tokenization_auto.py:1144, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1141 tokenizer_class_py, tokenizer_class_fast = TOKENIZER_MAPPING[type(config)]
#    1143 if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# -> 1144     return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1145 else:
#    1146     if tokenizer_class_py is not None:
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:2070, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2067     else:
#    2068         logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
# -> 2070 return cls._from_pretrained(
#    2071     resolved_vocab_files,
#    2072     pretrained_model_name_or_path,
#    2073     init_configuration,
#    2074     *init_inputs,
#    2075     token=token,
#    2076     cache_dir=cache_dir,
#    2077     local_files_only=local_files_only,
#    2078     _commit_hash=commit_hash,
#    2079     _is_local=is_local,
#    2080     trust_remote_code=trust_remote_code,
#    2081     **kwargs,
#    2082 )
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:2316, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2314 # Instantiate the tokenizer.
#    2315 try:
# -> 2316     tokenizer = cls(*init_inputs, **init_kwargs)
#    2317 except import_protobuf_decode_error():
#    2318     logger.info(
#    2319         "Unable to load tokenizer model from SPM, loading from TikToken will be attempted instead."
#    2320         "(Google protobuf error: Tried to load SPM model with non-SPM vocab file).",
#    2321     )
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/models/xlm_roberta/tokenization_xlm_roberta_fast.py:108, in XLMRobertaTokenizerFast.__init__(self, vocab_file, tokenizer_file, bos_token, eos_token, sep_token, cls_token, unk_token, pad_token, mask_token, **kwargs)
#      92 def __init__(
#      93     self,
#      94     vocab_file=None,
#    (...)    104 ):
#     105     # Mask token behave like a normal word, i.e. include the space before it
#     106     mask_token = AddedToken(mask_token, lstrip=True, rstrip=False) if isinstance(mask_token, str) else mask_token
# --> 108     super().__init__(
#     109         vocab_file,
#     110         tokenizer_file=tokenizer_file,
#     111         bos_token=bos_token,
#     112         eos_token=eos_token,
#     113         sep_token=sep_token,
#     114         cls_token=cls_token,
#     115         unk_token=unk_token,
#     116         pad_token=pad_token,
#     117         mask_token=mask_token,
#     118         **kwargs,
#     119     )
#     121     self.vocab_file = vocab_file
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/tokenization_utils_fast.py:139, in PreTrainedTokenizerFast.__init__(self, *args, **kwargs)
#     137     self.vocab_file = kwargs.get("vocab_file")
#     138     self.additional_special_tokens = kwargs.get("additional_special_tokens", [])
# --> 139     fast_tokenizer = convert_slow_tokenizer(self, from_tiktoken=True)
#     140     slow_tokenizer = None
#     141 else:
#
# File ~/Documents/Personal/mba-ia-bigdata-2025/tcc/tcc-analise-sentimentos-autos/notebooks/venv/lib/python3.13/site-packages/transformers/convert_slow_tokenizer.py:1739, in convert_slow_tokenizer(transformer_tokenizer, from_tiktoken)
#    1734     return TikTokenConverter(
#    1735         vocab_file=transformer_tokenizer.vocab_file,
#    1736         additional_special_tokens=transformer_tokenizer.additional_special_tokens,
#    1737     ).converted()
#    1738 except Exception:
# -> 1739     raise ValueError(
#    1740         f"Converting from SentencePiece and Tiktoken failed, if a converter for SentencePiece is available, provide a model path "
#    1741         f"with a SentencePiece tokenizer.model file."
#    1742         f"Currently available slow->fast converters: {list(SLOW_TO_FAST_CONVERTERS.keys())}"
#    1743     )
#
# ValueError: Converting from SentencePiece and Tiktoken failed, if a converter for SentencePiece is available, provide a model path with a SentencePiece tokenizer.model file.Currently available slow->fast converters: ['AlbertTokenizer', 'BartTokenizer', 'BarthezTokenizer', 'BertTokenizer', 'BigBirdTokenizer', 'BlenderbotTokenizer', 'CamembertTokenizer', 'CLIPTokenizer', 'CodeGenTokenizer', 'ConvBertTokenizer', 'DebertaTokenizer', 'DebertaV2Tokenizer', 'DistilBertTokenizer', 'DPRReaderTokenizer', 'DPRQuestionEncoderTokenizer', 'DPRContextEncoderTokenizer', 'ElectraTokenizer', 'FNetTokenizer', 'FunnelTokenizer', 'GPT2Tokenizer', 'HerbertTokenizer', 'LayoutLMTokenizer', 'LayoutLMv2Tokenizer', 'LayoutLMv3Tokenizer', 'LayoutXLMTokenizer', 'LongformerTokenizer', 'LEDTokenizer', 'LxmertTokenizer', 'MarkupLMTokenizer', 'MBartTokenizer', 'MBart50Tokenizer', 'MPNetTokenizer', 'MobileBertTokenizer', 'MvpTokenizer', 'NllbTokenizer', 'OpenAIGPTTokenizer', 'PegasusTokenizer', 'Qwen2Tokenizer', 'RealmTokenizer', 'ReformerTokenizer', 'RemBertTokenizer', 'RetriBertTokenizer', 'RobertaTokenizer', 'RoFormerTokenizer', 'SeamlessM4TTokenizer', 'SqueezeBertTokenizer', 'T5Tokenizer', 'UdopTokenizer', 'WhisperTokenizer', 'XLMRobertaTokenizer', 'XLNetTokenizer', 'SplinterTokenizer', 'XGLMTokenizer', 'LlamaTokenizer', 'CodeLlamaTokenizer', 'GemmaTokenizer', 'Phi3Tokenizer']

# %% [markdown]
# ## Testando com o dataset TweetEval (sentiment - inglês)
# ⚠️ Nota: TweetEval está em inglês, mas serve como referência inicial de benchmark.

# %%
dataset = load_dataset('tweet_eval', 'sentiment')
print(dataset)

# %% [markdown]
# ### Exemplo de avaliação com TweetEval (inglês)

# %%
exemplos = dataset['test']['text'][:5]
for texto in exemplos:
    print(texto)
    print(sentiment_pipeline(texto))
    print('-'*50)

# %% [markdown]
# ## Avaliação em Português
# Exemplo com frases simuladas sobre carros (HB20, Onix, Argo).

# %%
frases_pt = [
    'O HB20 é econômico, mas o acabamento poderia ser melhor.',
    'O Onix é muito confortável e tem ótimo custo-benefício.',
    'O Argo apresenta falhas no motor segundo alguns usuários.'
]

for frase in frases_pt:
    print(frase)
    print(sentiment_pipeline_pt(frase))
    print('-'*50)

# %% [markdown]
# ## Próximos passos
# - Expandir testes para coleções maiores de tweets/reclamações.
# - Comparar métricas de performance entre TweetEval (inglês) e modelos PT-BR.
# - Integrar resultados com o banco de dados e dashboard.
